# %%
import pandas as pd
import json
from nltk.tokenize import word_tokenize
import re
import cohere
import time

# %%
# =============================================================================
# SEZIONE 1: Caricamento topic representations
# -----------------------------------------------------------------------------

df = pd.read_csv("./Results/topics_overview.tsv", sep="\t")

# %%
# =============================================================================
# SEZIONE 2: Generazione etichette dei topic con LLM (Cohere)
# -----------------------------------------------------------------------------
# Questa sezione del notebook:
# 1) Inizializza il client Cohere con la propria API key.
# 2) Definisce un messaggio di sistema che istruisce il modello a produrre
#    un’etichetta breve (3–4 parole), in italiano, senza formattazioni o spiegazioni.
# 3) Scorre tutte le righe del DataFrame `df` ed estrae, per ciascuna riga,
#    le parole rappresentative del topic dalla colonna `Representation`.
# 4) Costruisce il prompt utente (“Words: ...\nLabel:”) e invia la richiesta
#    al modello `command-a-03-2025` tramite `co.chat(...)`.
# 5) Legge la risposta del modello, stampa la label e la aggiunge alla lista `labels`
#    (eventualmente da assegnare poi a `df['Label']`).
# 6) Inserisce una pausa di 60 secondi ogni 10 richieste (`time.sleep(60)`)
#    per rispettare i limiti di frequenza dell’API (rate limiting).
# =============================================================================


co = cohere.ClientV2(api_key="") # inserire la propria API key di cohere qui, vedi https://cohere.com/ (API gratuita)

# prompt da passare all'LLM. In inglese per cohere perchè il modello funziona meglio in inglese, ma si può modificare il prompt a piacere (anche in italiano)
system_message = f"""We perform topic modelling on a set of actions that an italian public administration might want to do.  
        The following words are all representative of the actions grouped in the same topic, the words are in decrescent order of relevance.
        You should find a label that describes the type of actions that this topic represents, in a short label (3 or 4 words max). Prefer substantives.
        Try to be very specific in your label. Only return one potential name in Italian. Output only the label. 
        Do not repeat the prompt. Do not use boldface. Do not add example or exaplanations. Only the label\n"""

index = 0 
labels = []
for i in range(len(df)):
    index = index + 1
    words = df['Representation'].iloc[i]
    prompt = f"Words: {words}\nLabel:"
    res = co.chat(
        model="command-a-03-2025",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},  

        ],
    )
    print(res.message.content[0].text)
    labels.append(res.message.content[0].text)

    if index %10==0: # ogni 10 richieste, pausa di 60 secondi per rispettare i limiti di frequenza dell'API
        time.sleep(60)
# Out:
# Servizi Sociali Comunitari
# Gestione Impianti Sportivi
# Promozione della lettura infantile
# Contributi per Attività Estive Minorenni
# Supporto Familiare e Comunitario
# Attività Estive Giovanili
# Iniziative Comunitarie e Collaborazioni Locali
# Attività Culturali e Spettacoli
# Iniziative contro violenza di genere
# Formazione e Lavoro Scolastico
# Sostegno alla Genitorialità
# Educazione Civica e Cittadinanza Attiva
# Servizi per Genitori e Bambini
# Promozione Culturale e Turistica
# Gestione e Sostenibilità Ambientale
# Gestione Servizi Infanzia
# Gestione Spazi e Attività Comunali
# Kit di benvenuto per neonati
# Assistenza Domiciliare Anziani
# Gestione Rifiuti Sanitari
# Gestione Alloggi e Residenze
# Gestione Orari Uffici Pubblici
# Gestione Appalti e Certificazioni
# Sicurezza Stradale Pedonale
# Servizi educativi per l'infanzia
# Prevenzione e contrasto ludopatia
# Servizi per l'infanzia
# Partecipazione Civica Attiva
# Inserimento Lavorativo Categorie Deboli
# Gestione Tariffe e Agevolazioni
# Alfabetizzazione Digitale Intergenerazionale
# Educazione Ambientale Scolastica
# Gestione Aree Verdi Urbane
# Servizi di Assistenza all'Infanzia
# Sostegno e Sensibilizzazione Comunitaria
# Gestione Percorsi Turistici
# Gestione Percorsi Naturalistici
# Prevenzione e Salute Femminile
# Gestione Comunicazione Digitale
# Infrastrutture per Mobilità Ciclistica Sostenibile
# Servizi Sanitari Pediatrici
# Attività Motorie e Formazione
# Gestione Ambientale ed Energetica
# Accesso Internet Pubblico
# Gestione Reclami e Proposte Cittadine
# Supporto Abitativo Inclusivo
# Attività Educative e Sociali
# Distribuzione Alimenti Solidale
# Attività Invernali e Skipass
# Attività Ricreative Estive
# Gestione e Valutazione Politiche Pubbliche
# Formazione Linguistica Specializzata
# Eventi Festivi e Ricreativi
# Sostegno Famiglie con Neonati
# Sostegno Economico Studenti
# Formazione e Tirocini Scolastici
# Politiche di Welfare Lavorativo
# Servizi Sanitari e Farmaceutici
# Gestione Servizi Educativi Estivi
# Promozione Attività Giovanili Comunitarie
# Gestione Illuminazione Sostenibile
# Attività Sportive e Ricreative
# Attività Educative e Prevenzione Dipendenze
# Prevenzione e contrasto bullismo
# Integrazione e Cittadinanza Attiva
# Servizi Bibliotecari Digitali
# Promozione Servizi e Agevolazioni
# Accesso agevolato piscine
# Sostegno Famiglie e Neonati
# Eventi Culturali Montani
# Comunicazione e Informazione ai Cittadini
# Promozione Turistica e Culturale
# Sicurezza e Sorveglianza Urbana
# Attività Intergenerazionali Comunitarie
# Gestione Rifiuti e Assistenza Domiciliare
# Sostegno Neogenitori e Nascita
# Agevolazioni fiscali per anziani
# Servizio di vigilanza scolastica
# Comunicazione e Segnalazioni Cittadine
# Gestione Tariffe Asili Nido
# Assistenza Abitativa Emergenza
# Gestione Servizi Sociali Territoriali
# Gestione emergenza profughi
# Promozione Educativa e Sociale
# Servizi di Assistenza e Cooperazione
# Sostegno Fornitura Energetica Domestica
# Comunicazione e Informazione Istituzionale
# Strutture Sportive Comunali
# Attività per il Benessere Fisico e Mentale
# Assistenza e Accoglienza Sociale
# Gestione Impianti Sportivi e Tariffe
# Formazione e Tirocini Professionali
# Gestione Vaccinazioni Anticovid
# Comunicazione e Coinvolgimento Comunitario
# Agevolazioni Trasporto Turistico
# Gestione Sicurezza Camini
# Servizi di Welfare Aziendale
# Organizzazione Eventi e Comunicazione Pubblica
# Gestione Rifiuti e Tasse Locali
# Gestione Risorse e Spazi Locali

# %%
# =============================================================================
# SEZIONE 3: Salvataggio risultati
# -----------------------------------------------------------------------------
# Questa sezione del notebook:
# 1) Aggiunge la colonna label al dataframe dei topic.
# 2) Esporta il dataframe aggiornato in un file tsv.
# =============================================================================

df['Label'] = labels
df.to_csv("./Results/topics_overview.tsv", sep="\t", index=False)
